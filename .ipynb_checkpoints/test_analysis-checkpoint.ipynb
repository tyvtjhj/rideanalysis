# %%
pip install fitparse gpxpy pandas
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: fitparse in .\.venv\Lib\site-packages (1.2.0)
# Requirement already satisfied: gpxpy in .\.venv\Lib\site-packages (1.6.2)
# Requirement already satisfied: pandas in .\.venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in .\.venv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#导入包
import fitparse
import gpxpy

# 相对路径
fit_path = './test_data/2026-06-09_摄氧量3030s41.fit'
gpx_path = './test_data/activity_23182812295.gpx'

# 读取 FIT 文件
fit_file = fitparse.FitFile(fit_path)

# 读取 GPX 文件
with open(gpx_path, 'r', encoding='utf-8') as f:
    gpx = gpxpy.parse(f)

print("FIT 文件读取成功")
print("GPX 文件读取成功")

# %%
fit_path = './test_data/2026-06-09_摄氧量3030s41.fit'
fit_file = fitparse.FitFile(fit_path)

# 查看所有消息类型
message_types = set()
for message in fit_file.get_messages():
    message_types.add(message.name)

print("FIT 文件中包含的消息类型:")
for msg_type in sorted(message_types):
    print(f"- {msg_type}")
# Out:
# FIT 文件中包含的消息类型:
# - file_creator
# - file_id
# - workout
# - workout_step

# %%
import fitparse

fit_path = './test_data/2026-06-09_摄氧量3030s41.fit'
fit_file = fitparse.FitFile(fit_path)

# 解析 workout 和 workout_step 消息
workouts = []
workout_steps = []

for message in fit_file.get_messages():
    if message.name == 'workout':
        workout_data = {}
        for field in message.fields:
            workout_data[field.name] = field.value
        workouts.append(workout_data)

    elif message.name == 'workout_step':
        step_data = {}
        for field in message.fields:
            step_data[field.name] = field.value
        workout_steps.append(step_data)

print("=== Workout (训练计划) ===")
for i, workout in enumerate(workouts):
    print(f"\n训练计划 {i+1}:")
    for key, value in workout.items():
        print(f"  {key}: {value}")

print("\n=== Workout Steps (训练步骤) ===")
for i, step in enumerate(workout_steps):
    print(f"\n步骤 {i+1}:")
    for key, value in step.items():
        print(f"  {key}: {value}")
# Out:
# === Workout (训练计划) ===
#
# 训练计划 1:
#   sport: cycling
#   wkt_name: 摄氧量30/30s 4*15*30s
#   num_valid_steps: 24
#
# === Workout Steps (训练步骤) ===
#
# 步骤 1:
#   wkt_step_name: None
#   duration_time: 180.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1126
#   custom_target_power_high: 1150
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 0
#   duration_type: time
#
# 步骤 2:
#   wkt_step_name: None
#   duration_time: 180.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1145
#   custom_target_power_high: 1168
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 1
#   duration_type: time
#
# 步骤 3:
#   wkt_step_name: None
#   duration_time: 180.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1161
#   custom_target_power_high: 1184
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 2
#   duration_type: time
#
# 步骤 4:
#   wkt_step_name: None
#   duration_time: 180.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1179
#   custom_target_power_high: 1202
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 3
#   duration_type: time
#
# 步骤 5:
#   wkt_step_name: None
#   duration_time: 180.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1196
#   custom_target_power_high: 1218
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 4
#   duration_type: time
#
# 步骤 6:
#   wkt_step_name: Recovery
#   duration_time: 240.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1115
#   custom_target_power_high: 1138
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 5
#   duration_type: time
#
# 步骤 7:
#   wkt_step_name: Hard
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1288
#   custom_target_power_high: 1310
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 6
#   duration_type: time
#
# 步骤 8:
#   wkt_step_name: Easy
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1115
#   custom_target_power_high: 1138
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 7
#   duration_type: time
#
# 步骤 9:
#   wkt_step_name: None
#   duration_step: 6
#   target_type: None
#   repeat_steps: 15
#   custom_target_value_low: None
#   custom_target_value_high: None
#   intensity: None
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 8
#   duration_type: repeat_until_steps_cmplt
#
# 步骤 10:
#   wkt_step_name: Recovery
#   duration_time: 480.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1114
#   custom_target_power_high: 1139
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 9
#   duration_type: time
#
# 步骤 11:
#   wkt_step_name: Hard
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1288
#   custom_target_power_high: 1310
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 10
#   duration_type: time
#
# 步骤 12:
#   wkt_step_name: Easy
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1115
#   custom_target_power_high: 1138
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 11
#   duration_type: time
#
# 步骤 13:
#   wkt_step_name: None
#   duration_step: 10
#   target_type: None
#   repeat_steps: 15
#   custom_target_value_low: None
#   custom_target_value_high: None
#   intensity: None
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 12
#   duration_type: repeat_until_steps_cmplt
#
# 步骤 14:
#   wkt_step_name: Recovery
#   duration_time: 480.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1114
#   custom_target_power_high: 1139
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 13
#   duration_type: time
#
# 步骤 15:
#   wkt_step_name: Hard
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1288
#   custom_target_power_high: 1310
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 14
#   duration_type: time
#
# 步骤 16:
#   wkt_step_name: Easy
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1115
#   custom_target_power_high: 1138
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 15
#   duration_type: time
#
# 步骤 17:
#   wkt_step_name: None
#   duration_step: 14
#   target_type: None
#   repeat_steps: 15
#   custom_target_value_low: None
#   custom_target_value_high: None
#   intensity: None
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 16
#   duration_type: repeat_until_steps_cmplt
#
# 步骤 18:
#   wkt_step_name: Recovery
#   duration_time: 480.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1114
#   custom_target_power_high: 1139
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 17
#   duration_type: time
#
# 步骤 19:
#   wkt_step_name: Hard
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1288
#   custom_target_power_high: 1310
#   intensity: active
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 18
#   duration_type: time
#
# 步骤 20:
#   wkt_step_name: Easy
#   duration_time: 30.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1115
#   custom_target_power_high: 1138
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 19
#   duration_type: time
#
# 步骤 21:
#   wkt_step_name: None
#   duration_step: 18
#   target_type: None
#   repeat_steps: 15
#   custom_target_value_low: None
#   custom_target_value_high: None
#   intensity: None
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 20
#   duration_type: repeat_until_steps_cmplt
#
# 步骤 22:
#   wkt_step_name: Recovery
#   duration_time: 900.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1161
#   custom_target_power_high: 1138
#   intensity: rest
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 21
#   duration_type: time
#
# 步骤 23:
#   wkt_step_name: Cool down
#   duration_time: 600.0
#   target_type: power
#   target_power_zone: 0
#   custom_target_power_low: 1093
#   custom_target_power_high: 1114
#   intensity: cooldown
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 22
#   duration_type: time
#
# 步骤 24:
#   wkt_step_name: None
#   duration_value: None
#   target_type: None
#   target_value: None
#   custom_target_value_low: None
#   custom_target_value_high: None
#   intensity: cooldown
#   unknown_19: None
#   unknown_20: None
#   unknown_21: None
#   unknown_22: None
#   message_index: 23
#   duration_type: open

# %%
import fitparse
import pandas as pd

fit_path = './test_data/2026-06-09_摄氧量3030s41.fit'
fit_file = fitparse.FitFile(fit_path)

workout_steps = []
for message in fit_file.get_messages('workout_step'):
    step = {}
    for field in message.fields:
        # 保留所有非 None 且有名字的字段
        if field.value is not None and not field.name.startswith('unknown'):
            step[field.name] = field.value
    workout_steps.append(step)

# 转为 DataFrame，自动包含所有字段
df = pd.DataFrame(workout_steps)

# 查看所有列名
print("所有列：", df.columns.tolist())
print(df)
# Out:
# 所有列： ['duration_time', 'target_type', 'target_power_zone', 'custom_target_power_low', 'custom_target_power_high', 'intensity', 'message_index', 'duration_type', 'wkt_step_name', 'duration_step', 'repeat_steps']
#     duration_time target_type  target_power_zone  custom_target_power_low  \
# 0           180.0       power                0.0                   1126.0
# 1           180.0       power                0.0                   1145.0
# 2           180.0       power                0.0                   1161.0
# 3           180.0       power                0.0                   1179.0
# 4           180.0       power                0.0                   1196.0
# 5           240.0       power                0.0                   1115.0
# 6            30.0       power                0.0                   1288.0
# 7            30.0       power                0.0                   1115.0
# 8             NaN         NaN                NaN                      NaN
# 9           480.0       power                0.0                   1114.0
# 10           30.0       power                0.0                   1288.0
# 11           30.0       power                0.0                   1115.0
# 12            NaN         NaN                NaN                      NaN
# 13          480.0       power                0.0                   1114.0
# 14           30.0       power                0.0                   1288.0
# 15           30.0       power                0.0                   1115.0
# 16            NaN         NaN                NaN                      NaN
# 17          480.0       power                0.0                   1114.0
# 18           30.0       power                0.0                   1288.0
# 19           30.0       power                0.0                   1115.0
# 20            NaN         NaN                NaN                      NaN
# 21          900.0       power                0.0                   1161.0
# 22          600.0       power                0.0                   1093.0
# 23            NaN         NaN                NaN                      NaN
#
#     custom_target_power_high intensity  message_index  \
# 0                     1150.0    active              0
# 1                     1168.0    active              1
# 2                     1184.0    active              2
# 3                     1202.0    active              3
# 4                     1218.0    active              4
# 5                     1138.0      rest              5
# 6                     1310.0    active              6
# 7                     1138.0      rest              7
# 8                        NaN       NaN              8
# 9                     1139.0      rest              9
# 10                    1310.0    active             10
# 11                    1138.0      rest             11
# 12                       NaN       NaN             12
# 13                    1139.0      rest             13
# 14                    1310.0    active             14
# 15                    1138.0      rest             15
# 16                       NaN       NaN             16
# 17                    1139.0      rest             17
# 18                    1310.0    active             18
# 19                    1138.0      rest             19
# 20                       NaN       NaN             20
# 21                    1138.0      rest             21
# 22                    1114.0  cooldown             22
# 23                       NaN  cooldown             23
#
#                duration_type wkt_step_name  duration_step  repeat_steps
# 0                       time           NaN            NaN           NaN
# 1                       time           NaN            NaN           NaN
# 2                       time           NaN            NaN           NaN
# 3                       time           NaN            NaN           NaN
# 4                       time           NaN            NaN           NaN
# 5                       time      Recovery            NaN           NaN
# 6                       time          Hard            NaN           NaN
# 7                       time          Easy            NaN           NaN
# 8   repeat_until_steps_cmplt           NaN            6.0          15.0
# 9                       time      Recovery            NaN           NaN
# 10                      time          Hard            NaN           NaN
# 11                      time          Easy            NaN           NaN
# 12  repeat_until_steps_cmplt           NaN           10.0          15.0
# 13                      time      Recovery            NaN           NaN
# 14                      time          Hard            NaN           NaN
# 15                      time          Easy            NaN           NaN
# 16  repeat_until_steps_cmplt           NaN           14.0          15.0
# 17                      time      Recovery            NaN           NaN
# 18                      time          Hard            NaN           NaN
# 19                      time          Easy            NaN           NaN
# 20  repeat_until_steps_cmplt           NaN           18.0          15.0
# 21                      time      Recovery            NaN           NaN
# 22                      time     Cool down            NaN           NaN
# 23                      open           NaN            NaN           NaN
